# %%
text_file = open("test.txt", "r")
lines = text_file.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-01286b4ca4c7> in <module>
# ----> 1 text_file = open("test.txt", "r")
#       2 lines = text_file.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
line = text_file.readline()
print(line)

# %%
print(lines)
# Out:
# ['                                                                         TESLA DIAGNOSTICS\n', '                                      4-109,Sri Venkateswara Swamy Temple Lane , Chandanagar,Hyd , - 500050, Email Id: tesla.cdnr@gmail.com\n', '\n', '                                                                 Phone No : 9000799249,42036799,040-23031720\n', '\n', '                                                                                 TEST MENU\n', '\n', 'CARDIOLOGY\n', '\n', '   SNo         Test    Name Of Test                  Methodology                    Sample/Volume        Temp     Referral Lab      Schedule   Turn around     MRP\n', '               Code                                                                                               Name                         time\n', '\n', '       1       CR001   2D ECHO                                                      ---Select---()                IH                                         1100.00\n', '\n', '       2       CR002   2D ECHO Color Doppler(PA                                     .()                           IH                                         1200.00\n', '                       EDIATRIC)\n', '\n', '       3       CR003   Fetal Echo                                                   ---Select---()                IH                                         1200.00\n', '\n', '       4       CR004   Fetal Echocardiography                                       ---Select---()                IH                                         1200.00\n', '\n', '       5       CR005   TMT (Treadmill Test (Stress                                  .()                           IH                                         1000.00\n', '                       Test)\n', '\n', '       6       CR006   ECG (Electro Cardio Gram)                                    .()                           IH                                          200.00\n', '\n', '\n', '\n', '\n', 'Page 1 of 86\n', '\x0cCLINICAL BIOCHEMISTRY\n', '\n', '   SNo         Test        Name Of Test                  Methodology                    Sample/Volume       Temp    Referral Lab   Schedule   Turn around    MRP\n', '               Code                                                                                                 Name                      time\n', '\n', '       7       24HTGL      Triglycerides(Chyle) - 24     GPO-PAP                        24 Hrs. Urine()             IH             DAILY      8 HRS         300.00\n', '                           Urine\n', '\n', '       8       ACR         Albumin Creatinine Ratio -    Spectrophotometry/Calculati    Urine(20ml)         2-8°C   IH             Daily      Same Day      450.00\n', '                           Spot Urine                    on\n', '\n', '       9       ALBUMIN     Albumin-Serum                 Spectrophotometry              Serum(2ml)          2-8°C   IH             Daily      Same Day      150.00\n', '\n', '      10       ALP         ALP (Alkaline Phosphatase     Spectrophotometry              Serum(2ml)          2-8°C   IH             Daily      Same Day      150.00\n', '                           )\n', '\n', '      11       ALT         ALT/SGPT                      Spectrophotometry              Serum(2ml)          2-8°C   IH             Daily      Same Day      150.00\n', '\n', '      12       AMY         Amylase - Serum               Spectrophotometry              Serum(2ml)          2-8°C   IH             Daily      Same Day      500.00\n', '\n', '      13       AMY-F       Amylase - Fluids              Spectrophotometry              Fluid.(2ml)         2-8°C   IH             Daily      Same Day      500.00\n', '\n', '      14       AMY-U       Amylase - Urine               Spectrophotometry              Urine(20ml)         2-8°C   IH             Daily      Same Day      500.00\n', '\n', '      15       APTT        APTT (PTTK)                   Clotting                       Citrate Plasma(2m   2-8°C   IH         ...

# %%
import csv

# Make a csv file.
mycsv = csv.writer(open('out.csv', 'w'))

# Write header for csv file.
mycsv.writerow(['SNo', 'Test Code', 'Name of Test', 'Methodology', 'Sample', 'Temp','Referral Lab time','MRP'])
# Out:
# 74

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-669ab929ac93> in <module>
# ----> 1 line = text_file.readline()
#
# ValueError: I/O operation on closed file.
